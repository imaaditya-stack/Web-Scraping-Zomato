# %% [markdown]
# # Web Scraping
#
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites. <br>
# In this notebook i have used <b>Zomato</b> Website to scrape the data of Top restuarants in my city using BeautifulSoup Library.<br>
# I have also cleaned the Scraped data and saved it in a csv format.<br>
# The Resturant data will contain <b>Name, Cuisines, Ratings, Votes, and Cost For Two People </b>
# ### BeautifulSoup Documentation : https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# ### Important Note
# Read through the website’s Terms and Conditions to understand how you can legally use the data. Most sites prohibit you from using the data for commercial purposes.

# %%
#Install Packages
#!pip install beautifulsoup4
#!pip install requests

# %%
#Importing Packages
import requests
from bs4 import BeautifulSoup
from pandas import DataFrame
import numpy

# %%
#Used headers/agent. 
#Using following code we can fake the agent.
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
response = requests.get("https://www.zomato.com/mumbai/ulhasnagar-restaurants",headers=headers)

# %%
content = response.content
#BeautifulSoup Object Initialization
soup = BeautifulSoup(content,"html.parser")

# %%
#Prinitng html doc of the webpage
#print(soup.prettify())

# %% [markdown]
# The data needs to scraped is wraped inside the div with class <b>search-snippet-card</b>

# %%
top_rest = soup.find_all("div",attrs={"class": "search-snippet-card"})
top_rest
# Out:
# [<div class="card search-snippet-card all_web_jumbo_impr_track all_web_jumbo_click_track search-card" data-total_jumbo_click_payload='[{"table":"jadtracking","payload":{"banner_id":"414483","bzone":"20802","campaign_id":"420306","category_id":"2","location_type":"subzone","location_id":"2407","display_page":"search","entity_type":"restaurant","entity_id":"44654","isNewAd":"34","ad_position":"1","slider_position":"1","slider_sequence":"2","creative_id":"0","data":"{\"type\":\"boost\",\"original_rank\":1,\"boost_type\":\"BOOST_TYPE_SEARCH_SCORE\",\"boosted_rank\":1,\"sort_type\":\"SORT_TYPE_DEFAULT\"}","action":"click"}}]' data-total_jumbo_impr_payload='[{"table":"jadtracking","payload":{"banner_id":"414483","bzone":"20802","campaign_id":"420306","category_id":"2","location_type":"subzone","location_id":"2407","display_page":"search","entity_type":"restaurant","entity_id":"44654","isNewAd":"34","ad_position":"1","slider_position":"1","slider_sequence":"2","creative_id":"0","data":"{\"type\":\"boost\",\"original_rank\":1,\"boost_type\":\"BOOST_TYPE_SEARCH_SCORE\",\"boosted_rank\":1,\"sort_type\":\"SORT_TYPE_DEFAULT\"}","action":"impression"}}]'>
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-1" data-res_id="44654" data-trprovider="">
#  <article class="search-result first">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/9/35079/f21cc3e96cf29f448dcce05aa791bb42_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/mcdonalds-ulhasnagar/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="zgold col-l-5 fontsize5">
#  <div class="row">SPONSORED</div>
#  </div>
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/quick-bites " title="Quick Bites in Ulhasnagar">Quick Bites</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/mcdonalds-ulhasnagar" title="mcdonalds Restaurant, Ulhasnagar">McDonald's
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-44654 res-rating-nf right level-6 bold" data-content="Good" data-res-id="44654" data-variation="mini inverted">
#                                          3.9
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-44654 grey-text fontsize5">347 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="1- 6, Ground Floor, Green Land Apartment, Block A -40, Gol Maidan, Ulhasnagar West, Ulhasnagar, Mumbai"> 1- 6, Ground Floor, Green Land Apartment, Block A -40, Gol Maidan, Ulhasnagar West, Ulhasnagar, Mumbai</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/burger" title="Burger">Burger</a>, <a href="https://www.zomato.com/mumbai/restaurants/fast-food" title="Fast Food">Fast Food</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹400</span></div>
#  <div class="res-timing clearfix" title="10 AM to 11 PM">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      10am – 11pm (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="025 12733521, +91 8928304165" data-res-name="McDonald's">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/mcdonalds-ulhasnagar/menu#tabtop" title="mcdonalds Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item" data-app_link="" data-class_name="o2_link" data-res_id="44654" data-source="search" href="https://www.zomato.com/restaurant?tab=order&amp;res_id=44654" style="background-color: #099E44;">
#  <div>
#  <div class="fontsize4 bold white action_btn_icon" data-icon="">Order Now</div>
#  <div class="clear ieclear"></div>
#  </div>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">85 more outlets in Mumbai, Ulhasnagar</div><a alt="McDonald's" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/mcdonalds-3-kalyan">
#  <div class="ui res_image_container">
#  <img alt="McDonald's" src="https://b.zmtcdn.com/data/pictures/chains/9/35079/2be67efb4302119d103affa1c5f85ee0.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              McDonald's
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  <a alt="McDonald's" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/mcdonalds-1-kalyan">
#  <div class="ui res_image_container">
#  <img alt="McDonald's" src="https://b.zmtcdn.com/data/pictures/chains/9/35079/2be67efb4302119d103affa1c5f85ee0.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              McDonald's
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  <a class="ui ta-right pt10 fontsize3 zred pb10 pr10" href="/mumbai/ulhasnagar-restaurants?cid=35079">See all outlets <span class="fontsize1">›</span></a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-2" data-res_id="35268" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/0/35240/3ee06b14d54749e3400635c946c07492_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/natural-ice-cream-ulhasnagar/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/dessert-parlour " title="Dessert Parlor in Ulhasnagar">Dessert Parlor</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/natural-ice-cream-ulhasnagar" title="natural ice cream Restaurant, Ulhasnagar">Natural Ice Cream
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-35268 res-rating-nf right level-7 bold" data-content="Very Good" data-res-id="35268" data-variation="mini inverted">
#                                          4.0
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-35268 grey-text fontsize5">93 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="2, Shri Sai Saran Apartments, Near Royal Residency, Gol Maidan, Thane, Ulhasnagar, Thane"> 2, Shri Sai Saran Apartments, Near Royal Residency, Gol Maidan, Thane, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/ice-cream" title="Ice Cream">Ice Cream</a>, <a href="https://www.zomato.com/mumbai/restaurants/desserts" title="Desserts">Desserts</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹300</span></div>
#  <div class="res-timing clearfix" title="12 Noon to 1 AM (Mon), 4:30 PM to 1 AM (Tue-Sun)">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      12noon – 1am (Mon),4:30pm – 1am (Tue-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="0251 2704770, 0251 3201500" data-res-name="Natural Ice Cream">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/natural-ice-cream-ulhasnagar/menu#tabtop" title="natural ice cream Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item has_o2_link disabled" data-app_link="" data-class_name="o2_link" data-href="https://www.zomato.com/restaurant?tab=order&amp;res_id=35268" data-res_id="35268" data-source="search">
#  <div><span class="fontsize4 bold action_btn_icon o2_closed_now" data-icon="">Order Now</span>
#  <div class="clear ieclear"></div>
#  <span class="fontsize5 o2_closed_now">
#                                      Currently Offline
#                                  </span>
#  </div>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">62 more outlets in Mumbai, Ulhasnagar</div><a alt="Natural Ice Cream" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/natural-ice-cream-dombivali-east">
#  <div class="ui res_image_container">
#  <img alt="Natural Ice Cream" src="https://b.zmtcdn.com/images/collections/a2_blurred.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Natural Ice Cream
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Dombivali East
#          </div>
#  </div>
#  </a>
#  <a alt="Natural Ice Cream" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/natural-ice-cream-kalyan">
#  <div class="ui res_image_container">
#  <img alt="Natural Ice Cream" src="https://b.zmtcdn.com/images/collections/a17_blurred.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Natural Ice Cream
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  <a class="ui ta-right pt10 fontsize3 zred pb10 pr10" href="/mumbai/ulhasnagar-restaurants?cid=35240">See all outlets <span class="fontsize1">›</span></a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-3" data-res_id="19058399" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/8/37108/dcae00f7f7bca2ab6a7ccd5655edd5fd_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/jumboking-1-ulhasnagar-thane/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/jumboking-1-ulhasnagar-thane" title="jumboking Restaurant, Ulhasnagar">Jumboking
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-19058399 res-rating-nf right level-7 bold" data-content="Very Good" data-res-id="19058399" data-variation="mini inverted">
#                                          4.2
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-19058399 grey-text fontsize5">45 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="Shop 3, Satnam Apartment D, Near Gol Maidan, Sadhu Vaswani Chowk, Ulhasnagar, Thane"> Shop 3, Satnam Apartment D, Near Gol Maidan, Sadhu Vaswani Chowk, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/burger" title="Burger">Burger</a>, <a href="https://www.zomato.com/mumbai/restaurants/fast-food" title="Fast Food">Fast Food</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹150</span></div>
#  <div class="res-timing clearfix" title="11 AM to 11 PM">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      11am – 11pm (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  <div class="res-offers clearfix">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Discount:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text" style=" ">
#  <img height="20" src="https://b.zmtcdn.com/data/o2_promo_yellow_logo.png"/>
#  <a class="zgreen" href="/mumbai/jumboking-1-ulhasnagar-thane">
#                                                                                          20% off on all orders
#                                          </a>
#  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="+91 9798676255" data-res-name="Jumboking">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/jumboking-1-ulhasnagar-thane/menu#tabtop" title="jumboking Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item" data-app_link="" data-class_name="o2_link" data-res_id="19058399" data-source="search" href="https://www.zomato.com/restaurant?tab=order&amp;res_id=19058399" style="background-color: #099E44;">
#  <div>
#  <div class="fontsize4 bold white action_btn_icon" data-icon="">Order Now</div>
#  <div class="clear ieclear"></div>
#  <div class="fontsize5 white mt5">20% OFF</div>
#  </div>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">103 more outlets in Mumbai, Ulhasnagar</div><a alt="Jumboking" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/jumboking-ulhasnagar-thane">
#  <div class="ui res_image_container">
#  <img alt="Jumboking" src="https://b.zmtcdn.com/images/collections/a1_blurred.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A">
#  </img></div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Jumboking
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Ulhasnagar
#          </div>
#  </div>
#  </a>
#  <a alt="Jumboking" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/jumboking-1-dombivali-west-thane">
#  <div class="ui res_image_container">
#  <img alt="Jumboking" src="https://b.zmtcdn.com/images/collections/a6_blurred.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Jumboking
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Dombivali West
#          </div>
#  </div>
#  </a>
#  <a class="ui ta-right pt10 fontsize3 zred pb10 pr10" href="/mumbai/ulhasnagar-restaurants?cid=37108">See all outlets <span class="fontsize1">›</span></a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-4" data-res_id="19273056" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/6/19273056/9ad8ee60d59c8d5a546f25068922b48d_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/jai-mata-di-fast-food-ulhasnagar-thane/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/quick-bites " title="Quick Bites in Ulhasnagar">Quick Bites</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/jai-mata-di-fast-food-ulhasnagar-thane" title="jai mata di fast food Restaurant, Ulhasnagar">Jai Mata Di Fast Food
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-19273056 res-rating-nf right level-5 bold" data-content="Average" data-res-id="19273056" data-variation="mini inverted">
#                                          3.4
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-19273056 grey-text fontsize5">16 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="Shop 178, Near Milan Apartment, Maya Gas Road, Gol Maidan, Ulhasnagar, Thane"> Shop 178, Near Milan Apartment, Maya Gas Road, Gol Maidan, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/chinese" title="Chinese">Chinese</a>, <a href="https://www.zomato.com/mumbai/restaurants/fast-food" title="Fast Food">Fast Food</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹200</span></div>
#  <div class="res-timing clearfix" title="5 PM to 12:30 AM">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      5pm – 12:30am (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="+91 9137446693" data-res-name="Jai Mata Di Fast Food">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/jai-mata-di-fast-food-ulhasnagar-thane/menu#tabtop" title="jai mata di fast food Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item has_o2_link disabled" data-app_link="" data-class_name="o2_link" data-href="https://www.zomato.com/restaurant?tab=order&amp;res_id=19273056" data-res_id="19273056" data-source="search">
#  <div><span class="fontsize4 bold action_btn_icon o2_closed_now" data-icon="">Order Now</span>
#  <div class="clear ieclear"></div>
#  <span class="fontsize5 o2_closed_now">
#                                      Currently Offline
#                                  </span>
#  </div>
#  </a>
#  </div>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-5" data-res_id="18758117" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/7/18758117/be1424ba28dba1f7a0b306463ddb2f48_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/ming-yang-ulhasnagar-thane/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/casual-dining " title="Casual Dining in Ulhasnagar">Casual Dining</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/ming-yang-ulhasnagar-thane" title="ming yang Restaurant, Ulhasnagar">Ming Yang
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-18758117 res-rating-nf right level-6 bold" data-content="Good" data-res-id="18758117" data-variation="mini inverted">
#                                          3.8
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-18758117 grey-text fontsize5">126 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="68, Kalyan Ambernath Road, Opposite Hanuman Mandir, Near Meera Hospital, Ulhasnagar, Thane"> 68, Kalyan Ambernath Road, Opposite Hanuman Mandir, Near Meera Hospital, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/chinese" title="Chinese">Chinese</a>, <a href="https://www.zomato.com/mumbai/restaurants/thai" title="Thai">Thai</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹950</span></div>
#  <div class="res-timing clearfix" title="1pm – 4pm, 7pm – 1am (Mon-Sun)">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      1pm – 4pm, 7pm – 1am (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="+91 7066593000" data-res-name="Ming Yang">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/ming-yang-ulhasnagar-thane/menu#tabtop" title="ming yang Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item has_o2_link disabled" data-app_link="" data-class_name="o2_link" data-href="https://www.zomato.com/restaurant?tab=order&amp;res_id=18758117" data-res_id="18758117" data-source="search">
#  <div><span class="fontsize4 bold action_btn_icon o2_closed_now" data-icon="">Order Now</span>
#  <div class="clear ieclear"></div>
#  <span class="fontsize5 o2_closed_now">
#                                      Currently Offline
#                                  </span>
#  </div>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">1 more outlet in Mumbai, Ulhasnagar</div><a alt="Ming Yang" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/ming-yang-kalyan">
#  <div class="ui res_image_container">
#  <img alt="Ming Yang" src="https://b.zmtcdn.com/data/pictures/chains/9/46899/2544040caec33a11fc85a92544a9513f.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Ming Yang
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-6" data-res_id="18245976" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/1/47211/34cb143d58dad35f16a85f3536a685ee_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/dominos-pizza-3-ulhasnagar/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/quick-bites " title="Quick Bites in Ulhasnagar">Quick Bites</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/dominos-pizza-3-ulhasnagar" title="dominos pizza Restaurant, Ulhasnagar">Domino's Pizza
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-18245976 res-rating-nf right level-6 bold" data-content="Good" data-res-id="18245976" data-variation="mini inverted">
#                                          3.8
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-18245976 grey-text fontsize5">108 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="Ground Floor, Vishal Mega Commercial Complex, Ulhasnagar, Mumbai"> Ground Floor, Vishal Mega Commercial Complex, Ulhasnagar, Mumbai</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/pizza" title="Pizza">Pizza</a>, <a href="https://www.zomato.com/mumbai/restaurants/fast-food" title="Fast Food">Fast Food</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹400</span></div>
#  <div class="res-timing clearfix" title="11 AM to 11 PM">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      11am – 11pm (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui two item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="0251 2530444" data-res-name="Domino's Pizza">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/dominos-pizza-3-ulhasnagar/menu#tabtop" title="dominos pizza Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">139 more outlets in Mumbai, Ulhasnagar</div><a alt="Domino's Pizza" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/dominos-pizza-ulhasnagar">
#  <div class="ui res_image_container">
#  <img alt="Domino's Pizza" src="https://b.zmtcdn.com/data/pictures/4/18959324/c2fcb207c9e4b3654f0634e661d63860.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Domino's Pizza
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Ulhasnagar
#          </div>
#  </div>
#  </a>
#  <a alt="Domino's Pizza" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/dominos-pizza-1-ulhasnagar">
#  <div class="ui res_image_container">
#  <img alt="Domino's Pizza" src="https://b.zmtcdn.com/data/pictures/4/18959324/c2fcb207c9e4b3654f0634e661d63860.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Domino's Pizza
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Ulhasnagar
#          </div>
#  </div>
#  </a>
#  <a class="ui ta-right pt10 fontsize3 zred pb10 pr10" href="/mumbai/ulhasnagar-restaurants?cid=47211">See all outlets <span class="fontsize1">›</span></a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-7" data-res_id="39582" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/2/39582/e2f36e322c25b365791c3fe6d6504255_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/amar-fast-food-restaurant-ulhasnagar-thane/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/quick-bites " title="Quick Bites in Ulhasnagar">Quick Bites</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/amar-fast-food-restaurant-ulhasnagar-thane" title="amar fast food restaurant Restaurant, Ulhasnagar">Amar Fast Food &amp; Restaurant
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-39582 res-rating-nf right level-6 bold" data-content="Good" data-res-id="39582" data-variation="mini inverted">
#                                          3.7
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-39582 grey-text fontsize5">346 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="169, Baba Shewadas Darbar, Near Municipal Corporation, Ulhasnagar, Thane"> 169, Baba Shewadas Darbar, Near Municipal Corporation, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/street-food" title="Street Food">Street Food</a>, <a href="https://www.zomato.com/mumbai/restaurants/chinese" title="Chinese">Chinese</a>, <a href="https://www.zomato.com/mumbai/restaurants/north-indian" title="North Indian">North Indian</a>, <a href="https://www.zomato.com/mumbai/restaurants/biryani" title="Biryani">Biryani</a>, <a href="https://www.zomato.com/mumbai/restaurants/fast-food" title="Fast Food">Fast Food</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹600</span></div>
#  <div class="res-timing clearfix" title="12noon – 12midnight (Mon, Tue, Thu, Fri, Sat, Sun), 12noon – 12:30am (Wed)">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      12noon – 12midnight (Mon, Tue, Thu, Fri, Sat...
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="+91 9503030909, +91 9321216060" data-res-name="Amar Fast Food &amp; Restaurant">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/amar-fast-food-restaurant-ulhasnagar-thane/menu#tabtop" title="amar fast food restaurant Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item has_o2_link disabled" data-app_link="" data-class_name="o2_link" data-href="https://www.zomato.com/restaurant?tab=order&amp;res_id=39582" data-res_id="39582" data-source="search">
#  <div><span class="fontsize4 bold action_btn_icon o2_closed_now" data-icon="">Order Now</span>
#  <div class="clear ieclear"></div>
#  <span class="fontsize5 o2_closed_now">
#                                      Currently Offline
#                                  </span>
#  </div>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">1 more outlet in Mumbai, Ulhasnagar</div><a alt="Amar Fast Food &amp; Restaurant" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/amar-fast-food-restaurant-kalyan">
#  <div class="ui res_image_container">
#  <img alt="Amar Fast Food &amp; Restaurant" src="https://b.zmtcdn.com/images/collections/a7_blurred.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Amar Fast Food &amp; Restaurant
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-8" data-res_id="19274353" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/1/18544061/54493eeadaba8a163cc91f11d7b4be59_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/box-office-cafe-bar-and-bistro-ulhasnagar-thane/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/quick-bites " title="Quick Bites in Ulhasnagar">Quick Bites</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/box-office-cafe-bar-and-bistro-ulhasnagar-thane" title="box office cafe bar bistro Restaurant, Ulhasnagar">Box Office Cafe Bar and Bistro
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-19274353 res-rating-nf right level-5 bold" data-content="Average" data-res-id="19274353" data-variation="mini inverted">
#                                          3.1
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-19274353 grey-text fontsize5">4 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="Gala 1-7, 1st Floor, Om Sai Arcade, Block A/36, Dada Kamal Parwani Marg, Near New Telephone Exchange, Ulhasnagar, Thane"> Gala 1-7, 1st Floor, Om Sai Arcade, Block A/36, Dada Kamal Parwani Marg, Near New Telephone Exchange, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/north-indian" title="North Indian">North Indian</a>, <a href="https://www.zomato.com/mumbai/restaurants/chinese" title="Chinese">Chinese</a>, <a href="https://www.zomato.com/mumbai/restaurants/continental" title="Continental">Continental</a>, <a href="https://www.zomato.com/mumbai/restaurants/fast-food" title="Fast Food">Fast Food</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹700</span></div>
#  <div class="res-timing clearfix" title="11:30 AM to 11 PM">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      11:30am – 11pm (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="+91 9730650427" data-res-name="Box Office Cafe Bar and Bistro">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/box-office-cafe-bar-and-bistro-ulhasnagar-thane/menu#tabtop" title="box office cafe bar bistro Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item has_o2_link disabled" data-app_link="" data-class_name="o2_link" data-href="https://www.zomato.com/restaurant?tab=order&amp;res_id=19274353" data-res_id="19274353" data-source="search">
#  <div><span class="fontsize4 bold action_btn_icon o2_closed_now" data-icon="">Order Now</span>
#  <div class="clear ieclear"></div>
#  <span class="fontsize5 o2_closed_now">
#                                      Currently Offline
#                                  </span>
#  </div>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">1 more outlet in Mumbai, Ulhasnagar</div><a alt="Box Office Cafe" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/box-office-cafe-kalyan">
#  <div class="ui res_image_container">
#  <img alt="Box Office Cafe" src="https://b.zmtcdn.com/data/pictures/chains/1/18544061/de8f7eaaa90845fb2cacb85d8385b514.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Box Office Cafe
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-9" data-res_id="19095067" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/images/placeholder_200.png" href="https://www.zomato.com/mumbai/hunger-ground-ulhasnagar-thane/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/hunger-ground-ulhasnagar-thane" title="hunger ground Restaurant, Ulhasnagar">Hunger Ground
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-19095067 res-rating-nf right level-6 bold" data-content="Good" data-res-id="19095067" data-variation="mini inverted">
#                                          3.7
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-19095067 grey-text fontsize5">57 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="Room 41 &amp;amp; 42, Ground Floor, Pawan Palace, Block C 11, Near Kaccharam Statue, Ulhasnagar, Thane"> Room 41 &amp; 42, Ground Floor, Pawan Palace, Block C 11, Near Kaccharam Statue, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/north-indian" title="North Indian">North Indian</a>, <a href="https://www.zomato.com/mumbai/restaurants/chinese" title="Chinese">Chinese</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹350</span></div>
#  <div class="res-timing clearfix" title="3pm – 2:30am (Mon-Sun)">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      3pm – 2:30am (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="+91 9206767678" data-res-name="Hunger Ground">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/hunger-ground-ulhasnagar-thane/menu#tabtop" title="hunger ground Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
# ...
#  <div class="ui res_image_container">
#  <img alt="Hotel Ballaleshwar" src="https://b.zmtcdn.com/images/collections/a15_blurred.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Hotel Ballaleshwar
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  <a alt="Hotel Ballaleshwar" class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/hotel-ballaleshwar-dombivali-east">
#  <div class="ui res_image_container">
#  <img alt="Hotel Ballaleshwar" src="https://b.zmtcdn.com/images/collections/a15_blurred.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              Hotel Ballaleshwar
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Dombivali East
#          </div>
#  </div>
#  </a>
#  <a class="ui ta-right pt10 fontsize3 zred pb10 pr10" href="/mumbai/ulhasnagar-restaurants?cid=18235077">See all outlets <span class="fontsize1">›</span></a>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-13" data-res_id="46354" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/4/46354/b42b21ff395d166ed19c631183e7a5f2_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/hardasmal-ulhasnagar/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/casual-dining " title="Casual Dining in Ulhasnagar">Casual Dining</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/hardasmal-ulhasnagar" title="hardasmal Restaurant, Ulhasnagar">Hardasmal
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-46354 res-rating-nf right level-6 bold" data-content="Good" data-res-id="46354" data-variation="mini inverted">
#                                          3.6
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-46354 grey-text fontsize5">137 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="Shop 2, Gargi Palace, Unit 5 &amp;amp; 6, Sheet 40, Netaji Road, Ulhasnagar, Thane"> Shop 2, Gargi Palace, Unit 5 &amp; 6, Sheet 40, Netaji Road, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/north-indian" title="North Indian">North Indian</a>, <a href="https://www.zomato.com/mumbai/restaurants/south-indian" title="South Indian">South Indian</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹450</span></div>
#  <div class="res-timing clearfix" title="12 Noon to 12 Midnight">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      12noon – 12midnight (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="0251 2704802, +91 9321549549" data-res-name="Hardasmal">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/hardasmal-ulhasnagar/menu#tabtop" title="hardasmal Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item has_o2_link disabled" data-app_link="" data-class_name="o2_link" data-href="https://www.zomato.com/restaurant?tab=order&amp;res_id=46354" data-res_id="46354" data-source="search">
#  <div><span class="fontsize4 bold action_btn_icon o2_closed_now" data-icon="">Order Now</span>
#  <div class="clear ieclear"></div>
#  <span class="fontsize5 o2_closed_now">
#                                      Currently Offline
#                                  </span>
#  </div>
#  </a>
#  </div>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-14" data-res_id="44657" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/7/44657/f6239d2874f4ecef1c6e8088f91bc2bf_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/roti-n-ulhasnagar/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/quick-bites " title="Quick Bites in Ulhasnagar">Quick Bites</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/roti-n-ulhasnagar" title="roti n Restaurant, Ulhasnagar">Roti N
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-44657 res-rating-nf right level-6 bold" data-content="Good" data-res-id="44657" data-variation="mini inverted">
#                                          3.6
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-44657 grey-text fontsize5">393 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="5, Sai Darshan Apartment, Near Kachharam Statue, Ulhasnagar, Thane"> 5, Sai Darshan Apartment, Near Kachharam Statue, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/fast-food" title="Fast Food">Fast Food</a>, <a href="https://www.zomato.com/mumbai/restaurants/chinese" title="Chinese">Chinese</a>, <a href="https://www.zomato.com/mumbai/restaurants/north-indian" title="North Indian">North Indian</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹600</span></div>
#  <div class="res-timing clearfix" title="12:30pm – 12midnight (Mon-Sun)">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      12:30pm – 12midnight (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="0251 2561008, 0251 2708130" data-res-name="Roti N">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/roti-n-ulhasnagar/menu#tabtop" title="roti n Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item has_o2_link disabled" data-app_link="" data-class_name="o2_link" data-href="https://www.zomato.com/restaurant?tab=order&amp;res_id=44657" data-res_id="44657" data-source="search">
#  <div><span class="fontsize4 bold action_btn_icon o2_closed_now" data-icon="">Order Now</span>
#  <div class="clear ieclear"></div>
#  <span class="fontsize5 o2_closed_now">
#                                      Currently Offline
#                                  </span>
#  </div>
#  </a>
#  </div>
#  </div>, <div class="card search-snippet-card search-card">
#  <div class="content">
#  <div class="js-search-result-li even status 1" data-position="1-15" data-res_id="18594450" data-trprovider="">
#  <article class="search-result">
#  <div class="pos-relative clearfix">
#  <div class="row">
#  <div class="col-s-6 col-m-4">
#  <div class="search_left_featured clearfix">
#  <a class="feat-img lazy" data-original="https://b.zmtcdn.com/data/pictures/chains/3/18140523/a3ad3da8fe6d820dffe85835fa65ba7c_featured_v2.jpg?fit=around%7C200%3A200&amp;crop=200%3A200%3B%2A%2C%2A" href="https://www.zomato.com/mumbai/the-belgian-waffle-co-ulhasnagar-thane/info" style="  background-image:url(https://b.zmtcdn.com/images/placeholder_200.png);background-repeat: repeat;"></a>
#  </div>
#  </div>
#  <div class="col-s-16 col-m-12 pl0">
#  <div class="row">
#  <div class="col-s-12">
#  <div class="res-snippet-small-establishment mt5" style="margin-bottom: 7px;"><a class="zdark ttupper fontsize6" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants/dessert-parlour " title="Dessert Parlor in Ulhasnagar">Dessert Parlor</a></div>
#  <a class="result-title hover_feedback zred bold ln24 fontsize0" data-result-type="ResCard_Name" href="https://www.zomato.com/mumbai/the-belgian-waffle-co-ulhasnagar-thane" title="belgian waffle co Restaurant, Ulhasnagar">The Belgian Waffle Co.
#                                      </a>
#  <div class="clear"></div>
#  <a class="ln24 search-page-text mr10 zblack search_result_subzone left" href="https://www.zomato.com/mumbai/ulhasnagar-restaurants" title="Restaurants in Ulhasnagar"><b>Ulhasnagar</b></a>
#  </div>
#  <div class="ta-right floating search_result_rating col-s-4 clearfix" style="line-height: 14px;">
#  <div class="rating-popup rating-for-18594450 res-rating-nf right level-6 bold" data-content="Good" data-res-id="18594450" data-variation="mini inverted">
#                                          3.8
#                                      </div>
#  <div class="clear mb5"></div>
#  <!-- show the vote count only if there's a rating -->
#  <span class="rating-votes-div-18594450 grey-text fontsize5">163 votes</span>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-m-16 search-result-address grey-text nowrap ln22" style=" max-width:370px; " title="Shop 3, Sai Arcade, Madhuban Chowk, Gol Maidan, Ulhasnagar, Thane"> Shop 3, Sai Arcade, Madhuban Chowk, Gol Maidan, Ulhasnagar, Thane</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ui divider"></div>
#  <div class="search-page-text clearfix row">
#  <div class="clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cuisines: </span><span class="col-s-11 col-m-12 nowrap pl0"><a href="https://www.zomato.com/mumbai/restaurants/desserts" title="Desserts">Desserts</a>, <a href="https://www.zomato.com/mumbai/restaurants/beverages" title="Beverages">Beverages</a></span></div>
#  <div class="res-cost clearfix"><span class="col-s-5 col-m-4 ttupper fontsize5 grey-text">Cost for two:</span><span class="col-s-11 col-m-12 pl0">₹300</span></div>
#  <div class="res-timing clearfix" title="12 Noon to 1:30 AM">
#  <span class="col-s-5 col-m-4 ttupper fontsize5 grey-text left">Hours:</span>
#  <div class="col-s-11 col-m-12 pl0 search-grid-right-text">
#                                      12noon – 1:30am (Mon-Sun)
#                                                                      </div>
#  <div class="clear"></div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </div>
#  <div class="ui three item menu search-result-action mt0">
#  <a class="item res-snippet-ph-info" data-phone-no-str="+91 8149070460, +91 9869800580" data-res-name="The Belgian Waffle Co.">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">Call</span>
#  </a>
#  <a class="item result-menu" data-result-type="ResCard_Menu" href="/mumbai/the-belgian-waffle-co-ulhasnagar-thane/menu#tabtop" title="belgian waffle co Menu">
#  <span class="zdark fontsize4 bold action_btn_icon" data-icon="">
#                          View Menu
#                      </span>
#  </a>
#  <a class="item" data-app_link="" data-class_name="o2_link" data-res_id="18594450" data-source="search" href="https://www.zomato.com/restaurant?tab=order&amp;res_id=18594450" style="background-color: #099E44;">
#  <div>
#  <div class="fontsize4 bold white action_btn_icon" data-icon="">Order Now</div>
#  <div class="clear ieclear"></div>
#  </div>
#  </a>
#  </div>
#  <div class="ui col-l-16 fontsize5 grey-text">56 more outlets in Mumbai, Ulhasnagar</div><a alt="The Belgian Waffle Co." class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/the-belgian-waffle-co-kalyan">
#  <div class="ui res_image_container">
#  <img alt="The Belgian Waffle Co." src="https://b.zmtcdn.com/data/pictures/3/18502043/cfbda35382090ddbf5128a946c235f74.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              The Belgian Waffle Co.
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Kalyan
#          </div>
#  </div>
#  </a>
#  <a alt="The Belgian Waffle Co." class="ui col-l-16 search_chain_bottom_snippet" href="https://www.zomato.com/mumbai/the-belgian-waffle-co-1-dombivali-east-thane">
#  <div class="ui res_image_container">
#  <img alt="The Belgian Waffle Co." src="https://b.zmtcdn.com/data/pictures/3/18502043/cfbda35382090ddbf5128a946c235f74.jpg?fit=around%7C100%3A100&amp;crop=100%3A100%3B%2A%2C%2A"/>
#  </div>
#  <div class="ui res_details_container">
#  <div class="ui res_name bold">
#              The Belgian Waffle Co.
#          </div>
#  <div class="ui res_subzone_name grey-text">
#              Dombivali East
#          </div>
#  </div>
#  </a>
#  <a class="ui ta-right pt10 fontsize3 zred pb10 pr10" href="/mumbai/ulhasnagar-restaurants?cid=18140523">See all outlets <span class="fontsize1">›</span></a>
#  </div>]

# %% [markdown]
# Now we have the whole card we will look for individual features we need to scrape which are :
# 1. Name of the Restuarant
# 2. Cuisines
# 3. Ratings
# 4. Votes
# 5. Cost For Two

# %%
#This line of code gives name of the restuarnt
top_rest[0].find("a",attrs={"class":"result-title"}).text.strip()
# Out:
# "McDonald's"

# %%
#This line of code gives Votes
top_rest[11].find("span",attrs={"class":"grey-text"}).text.strip()
# Out:
# 'Cuisines:'

# %%
#This line of code gives Ratings
top_rest[0].find("div",attrs={"class":"rating-popup"}).text.strip()
# Out:
# '3.9'

# %%
#This line of code gives name of the restuarnt Cuisines
top_rest[0].find("span",attrs={"class":"col-s-11"}).text
# Out:
# 'Burger, Fast Food'

# %%
#This line of code gives Cost For Two
top_rest[0].find("span",attrs={"class":"col-s-11 col-m-12 pl0"}).text
# Out:
# '₹400'

# %% [markdown]
# Now we know the code to scrape the individual features we now have to scrape these features for all of the resturants. I have a created a custom class <b>Scraping</b> to do the work.

# %%
class Scraping:
    
    def __init__(self,url,headers):
        """
        Param url: URL of the website
        Param headers: User Agent
        """
        self.url = url
        self.headers = headers
    
    def get_data(self):
        """
        This function returns scraped data in the form of a list containing dictionaries
        """
        #Empty list to store the data
        datalist = []
        
        #Loop through each webpage
        #For my city Zomato has 15 webpages where each page having details of 15 restuarants
        for page in range(15):
            
            #Getting request
            response = requests.get("{}&page={}".format(self.url,page+1)
                                    ,headers=self.headers)
            content = response.content
            
            #BeautifulSoup Object Initialization
            soup = BeautifulSoup(content,"html.parser")
            
            #Getting the element from which we will find the data we required
            top_rest = soup.find_all("div",attrs={"class": "search-snippet-card"})
            
            #Loop through each element
            for i in range(len(top_rest)):
                #Empty dictionary to store the data in key-value pair
                dataframe = {}
                
                #Try except blocks
                #Try block store the data
                #If exception occurs it will store empty string
                
                #Restuarant Name
                try:
                    dataframe['Restaurant']=top_rest[i].find("a",attrs={"class":"result-title"}).text.strip()
                except:
                    
                    dataframe['Restaurant']=''
                
                #Votes
                try:
                    dataframe['Votes']=top_rest[i].find("span",attrs={"class":"grey-text"}).text
                except:
                    dataframe['Votes']=''
                
                #Ratings
                try:    
                    dataframe['Ratings']=top_rest[i].find("div",attrs={"class":"rating-popup"}).text.strip()
                except:
                    dataframe['Ratings']=''
                
                #Cuisines
                try:
                    dataframe['Cuisines']=top_rest[i].find("span",attrs={"class":"col-s-11"}).text
                except:
                    dataframe['Cuisines']=''
                
                #Cost For Two
                try:
                    dataframe['Cost For Two']=top_rest[i].find("span",attrs={"class":"col-s-11 col-m-12 pl0"}).text
                except:
                    dataframe['Cost For Two']=''
                
                #Append each dictionary to datalist
                datalist.append(dataframe)
        return datalist

# %%
#Creating an object of the class Scraping
myObject = Scraping(url = "https://www.zomato.com/mumbai/ulhasnagar-restaurants?nearby=0",headers = headers)

# %%
#Calling method get_data()
data_in_list = myObject.get_data()

# %%
#View top 5 values
data_in_list[:5]
# Out:
# [{'Restaurant': "McDonald's",
#   'Votes': '347 votes',
#   'Ratings': '3.9',
#   'Cuisines': 'Burger, Fast Food',
#   'Cost For Two': '₹400'},
#  {'Restaurant': 'Natural Ice Cream',
#   'Votes': '93 votes',
#   'Ratings': '4.0',
#   'Cuisines': 'Ice Cream, Desserts',
#   'Cost For Two': '₹300'},
#  {'Restaurant': 'Jumboking',
#   'Votes': '45 votes',
#   'Ratings': '4.2',
#   'Cuisines': 'Burger, Fast Food',
#   'Cost For Two': '₹150'},
#  {'Restaurant': 'Jai Mata Di Fast Food',
#   'Votes': '16 votes',
#   'Ratings': '3.4',
#   'Cuisines': 'Chinese, Fast Food',
#   'Cost For Two': '₹200'},
#  {'Restaurant': 'Ming Yang',
#   'Votes': '126 votes',
#   'Ratings': '3.8',
#   'Cuisines': 'Chinese, Thai',
#   'Cost For Two': '₹950'}]

# %% [markdown]
# We will save the data frame data to CSV format which is easily readable.

# %%
#First convert the list into a dataframe
data = DataFrame(data=data_in_list,columns=["Restaurant","Cuisines","Ratings","Votes","Cost For Two"])

# %%
data.head()
# Out:
#               Restaurant             Cuisines Ratings      Votes Cost For Two
# 0             McDonald's    Burger, Fast Food     3.9  347 votes         ₹400
# 1      Natural Ice Cream  Ice Cream, Desserts     4.0   93 votes         ₹300
# 2              Jumboking    Burger, Fast Food     4.2   45 votes         ₹150
# 3  Jai Mata Di Fast Food   Chinese, Fast Food     3.4   16 votes         ₹200
# 4              Ming Yang        Chinese, Thai     3.8  126 votes         ₹950

# %%
data.shape
# Out:
# (221, 5)

# %% [markdown]
# The total entries we got is 221

# %%
data["Ratings"].unique()
# Out:
# array(['3.9', '4.0', '4.2', '3.4', '3.8', '3.7', '3.1', '3.6', '3.5',
#        '3.3', 'NEW', '2.9', '3.2', '-', '3.0', '2.6', '2.7', '2.5'],
#       dtype=object)

# %% [markdown]
# As we can see the Ratings column has <b>NEW</b> and <b>-</b> values

# %%
data["Votes"].unique()
# Out:
# array(['347 votes', '93 votes', '45 votes', '16 votes', '126 votes',
#        '108 votes', '346 votes', '4 votes', '57 votes', '101 votes',
#        '51 votes', 'Cuisines: ', '137 votes', '393 votes', '163 votes',
#        '33 votes', '9 votes', '21 votes', '206 votes', '14 votes',
#        '103 votes', '63 votes', '71 votes', '32 votes', '25 votes',
#        '46 votes', '11 votes', '91 votes', '7 votes', '17 votes',
#        '27 votes', '56 votes', '12 votes', '50 votes', '67 votes',
#        '18 votes', '13 votes', '5 votes', '8 votes', '191 votes',
#        '42 votes', '76 votes', '61 votes', '129 votes', '6 votes',
#        '40 votes', '323 votes', '69 votes', '105 votes', '89 votes',
#        '97 votes', '158 votes', '38 votes', '60 votes', '24 votes',
#        '35 votes', '15 votes', '28 votes', '52 votes', '10 votes',
#        '22 votes', '241 votes', '19 votes', '47 votes', '107 votes',
#        '82 votes', '49 votes', '62 votes', '118 votes', '53 votes',
#        '20 votes', '131 votes', '95 votes', '159 votes'], dtype=object)

# %% [markdown]
# The Votes column has some values as <b>Cuisines:</b>. This is becaue some restuarants did not contain any votes.

# %%
data["Cost For Two"].unique()
# Out:
# array(['₹400', '₹300', '₹150', '₹200', '₹950', '₹600', '₹700', '₹350',
#        '₹500', '₹450', '₹250', '₹750', '₹650', '₹850', '₹1,000', '₹1,600',
#        '₹900', '₹1,500', '₹800', '₹100', '₹50', '₹1,200', '₹1,300',
#        '₹550'], dtype=object)

# %% [markdown]
# The Cost For Two column has the data in object data type

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# I have replaced some irrelevant values

# %%
#Replace with 0 Ratings
data["Ratings"] = numpy.where((data["Ratings"]=="NEW") | (data["Ratings"]=="-"),0.0,data["Ratings"])

# %%
#Replace with 0 votes
data["Votes"] = numpy.where((data["Votes"]=="Cuisines: "),"0 votes",data["Votes"])
#Removing votes strig and convert to int dtype
data['Votes'] = data['Votes'].str.replace(r'\D+', '').astype('int')

# %%
#Cleaning the Cost For Two column
data['Cost For Two'] = data['Cost For Two'].str.replace(r'\D+', '').astype('int')

# %%
#Viewing data after cleaning
data.iloc[:10,:]
# Out:
#                        Restaurant  \
# 0                      McDonald's
# 1               Natural Ice Cream
# 2                       Jumboking
# 3           Jai Mata Di Fast Food
# 4                       Ming Yang
# 5                  Domino's Pizza
# 6     Amar Fast Food & Restaurant
# 7  Box Office Cafe Bar and Bistro
# 8                   Hunger Ground
# 9               Diet With Delight
#
#                                             Cuisines Ratings  Votes  \
# 0                                  Burger, Fast Food     3.9    347
# 1                                Ice Cream, Desserts     4.0     93
# 2                                  Burger, Fast Food     4.2     45
# 3                                 Chinese, Fast Food     3.4     16
# 4                                      Chinese, Thai     3.8    126
# 5                                   Pizza, Fast Food     3.8    108
# 6  Street Food, Chinese, North Indian, Biryani, F...     3.7    346
# 7      North Indian, Chinese, Continental, Fast Food     3.1      4
# 8                              North Indian, Chinese     3.7     57
# 9  Chinese, Fast Food, Street Food, Healthy Food,...     3.8    101
#
#    Cost For Two
# 0           400
# 1           300
# 2           150
# 3           200
# 4           950
# 5           400
# 6           600
# 7           700
# 8           350
# 9           350

# %% [markdown]
# Now we will save the data frame data to CSV format which is easily readable.

# %%
data.to_csv(path_or_buf='zomato_res.csv',sep=",",index=False,encoding='utf-8')
#The above code will create a CSV file named zomato_res.

# %% [markdown]
# # Conclusion
# Successfully scraped the data from zomato website and saved the data in csv format
